# %%
#Imports
# !pip3 install langchain_community
from langchain_community.llms import Ollama
import json
import os
import pandas as pd
# Out:
# Requirement already satisfied: langchain_community in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (1.2.5)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (0.5.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.0)
# Requirement already satisfied: certifi in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.2)
# Requirement already satisfied: greenlet>=1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)

# %%
# 1. Configuration
MEMORY_FILE = 'cache_category.json'
MODEL = 'expense-classifier-eng'

# %%
# 2. This function loads the memory from a JSON file
def load_memory():
    if os.path.exists(MEMORY_FILE):
        try:
            with open(MEMORY_FILE, 'r', encoding='utf-8') as f:
                return json.load(f)
        except json.JSONDecodeError:
            return {}  # If file is empty or invalid, start fresh
    return {}

# %%
# 3. This function saves the memory to a JSON file
def save_memory(memory):
    with open(MEMORY_FILE, 'w', encoding='utf-8') as f:
        json.dump(memory, f, indent=4, ensure_ascii=False)

# %%
#3.5 The idea is to only use Ollama on new cases, here I link the Ollama model created for expense classification. 
llm = Ollama(model=MODEL, base_url="http://localhost:11434")
# Out:
# C:\Users\josee\AppData\Local\Temp\ipykernel_20712\2922302967.py:2: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model=MODEL, base_url="http://localhost:11434")

# %%
# 4. Rationale to classify expenses
def obtain_category(description, memory):
    # Handle NaN or non-string values
    if pd.isna(description) or not isinstance(description, str):
        return "No Description"
    
    # clean the data (mayúsculas/minúsculas)
    description_clean = description.strip().upper()
    
    # A: Check on the dicctionary whether we already know it
    if description_clean in memory:
        return memory[description_clean]

    # B: If it's new we ask Ollama
    print(f"Asking the IA about: {description}...")
    try:
        category = llm.invoke(f"Clasifica: {description}").strip()
        
        # Save in memory for future cases
        memory[description_clean] = category
        return category
    except Exception as e:
        print(f"Error with Ollama: {e}")
        return "Not Classified"

# %% [markdown]
# ### Execution

# %%
known_dictionary = load_memory()
#Read the transaction data from the raw data folder
df = pd.read_csv('raw data/transactions_2022_2023.csv')
df.head()
# Out:
#          Date        Name / Description Expense/Income  Amount (EUR)
# 0  2023-12-30           Belastingdienst        Expense          9.96
# 1  2023-12-30               Tesco Breda        Expense         17.53
# 2  2023-12-30   Monthly Appartment Rent        Expense        451.00
# 3  2023-12-30  Vishandel Sier Amsterdam        Expense         12.46
# 4  2023-12-29         Selling Paintings         Income         13.63

# %%
# Lambda function to apply the classification using the known dictionary
df['Category'] = df['Name / Description'].apply(lambda x: obtain_category(x, known_dictionary))

# Saves the updated memory
save_memory(known_dictionary)

# Save the final result for a dashboard
df.to_csv('classified_expenses.csv', index=False)

print("Expense classification completed and saved to classified_expenses.csv")
# Out:
# Asking the IA about: Belastingdienst...
# Asking the IA about: Tesco Breda...
# Asking the IA about: Monthly Appartment Rent...
# Asking the IA about: Vishandel Sier Amsterdam...
# Asking the IA about: Selling Paintings...
# Asking the IA about: Spotify Ab By Adyen...
# Asking the IA about: Tk Maxx Amsterdam Da...
# Asking the IA about: Consulting...
# Asking the IA about: Aidsfonds...
# Asking the IA about: Tls Bv Inz Ov-Chipkaart...
# Asking the IA about: Etos Amsterdam...
# Asking the IA about: Beta Boulders Ams Amsterdam...
# Asking the IA about: Salary...
# Asking the IA about: Bouldermuur Bv Amsterdam...
# Asking the IA about: Birtat Restaurant Amsterdam...
# Asking the IA about: Freelancing...
# Asking the IA about: Tikkie...
# Asking the IA about: Blogging...
# Asking the IA about: Taxi Utrecht...
# Asking the IA about: Apple Services...
# Asking the IA about: Amazon Lux...
# Asking the IA about: Classpass* Monthly...
# Asking the IA about: Audible Uk AdblCo/Pymt Gbr...
# Expense classification completed and saved to classified_expenses.csv
