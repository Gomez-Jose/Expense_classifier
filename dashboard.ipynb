# %%
# !pip install plotly panel nbformat
# Out:
# Requirement already satisfied: plotly in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (6.5.0)
# Requirement already satisfied: panel in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (1.8.5)
# Requirement already satisfied: nbformat in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (5.10.4)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from plotly) (2.14.0)
# Requirement already satisfied: packaging in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from plotly) (25.0)
# Requirement already satisfied: bleach in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (6.3.0)
# Requirement already satisfied: bokeh<3.9.0,>=3.7.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (3.8.1)
# Requirement already satisfied: linkify-it-py in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (2.0.3)
# Requirement already satisfied: markdown in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (3.10)
# Requirement already satisfied: markdown-it-py in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (0.5.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (2.3.3)
# Requirement already satisfied: param<3.0,>=2.1.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (2.3.1)
# Requirement already satisfied: pyviz-comms>=2.0.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (3.0.6)
# Requirement already satisfied: requests in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from panel) (4.15.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (1.3.3)
# Requirement already satisfied: numpy>=1.16 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (2.3.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in c:\users\josee\appdata\roaming\python\python313\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (6.5.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (2025.11.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\josee\appdata\roaming\python\python313\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\josee\appdata\roaming\python\python313\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from Jinja2>=2.9->bokeh<3.9.0,>=3.7.0->panel) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\josee\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->panel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->panel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->panel) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->panel) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from linkify-it-py->panel) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from requests->panel) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from requests->panel) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from requests->panel) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josee\appdata\local\programs\python\python313\lib\site-packages (from requests->panel) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\josee\appdata\roaming\python\python313\site-packages (from tqdm->panel) (0.4.6)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import panel as pn

# %%
#Read transaction data
df = pd.read_csv('classified_expenses.csv')
#add year and month columns
df['Year'] = pd.to_datetime(df['Date']).dt.year
df['Month'] = pd.to_datetime(df['Date']).dt.month_name()
df.head()
# Out:
#          Date        Name / Description Expense/Income  Amount (EUR)  \
# 0  2023-12-30           Belastingdienst        Expense          9.96
# 1  2023-12-30               Tesco Breda        Expense         17.53
# 2  2023-12-30   Monthly Appartment Rent        Expense        451.00
# 3  2023-12-30  Vishandel Sier Amsterdam        Expense         12.46
# 4  2023-12-29         Selling Paintings         Income         13.63
#
#         Category  Year     Month
# 0        Savings  2023  December
# 1           Food  2023  December
# 2        Housing  2023  December
# 3        Housing  2023  December
# 4  Entertainment  2023  December

# %%
#When I have an Income I want the category to be the description
df['Category'] = np.where(df['Expense/Income'] == 'Income', df['Name / Description'], df['Category'])

# %% [markdown]
# ## Make pie chart

# %%
def make_pie_chart(df,year, label):
    #Filter data for expense transactions.
    filtered = df[(df['Expense/Income'] == label) & (df['Year'] == year)]

    color_scale = px.colors.qualitative.Set2

    pie_fig = px.pie(filtered, values = 'Amount (EUR)', names = 'Category', title = f'{label} Distribution for {year}', color_discrete_sequence=color_scale)
    pie_fig.update_traces(textposition='inside', direction = "clockwise", hole = 0.2,  textinfo='percent+label')

    total_expense = df[(df['Expense/Income'] == 'Expense') & (df['Year'] == year)]['Amount (EUR)'].sum()
    total_income = df[(df['Expense/Income'] == 'Income') & (df['Year'] == year)]['Amount (EUR)'].sum()

    if label == 'Expense':
        total_text = '€' + str(round(total_expense,2))

        #Saving rates
        saving_rate = round((total_income - total_expense) / total_income * 100,2)
        saving_rate_text = "Saving rate" + str(saving_rate) + '%'
    else:
        saving_rate = ""
        saving_rate_text = ""
        total_text = '€' + str(round(total_income,2))

        pie_fig.update_layout(uniformtext_minsize=10, 
                        uniformtext_mode='hide',
                        title=dict(text=label+" Breakdown " + str(year) + saving_rate_text),
                        # Add annotations in the center of the donut.
                        annotations=[
                            dict(
                                text=total_text, 
                                # Square unit grid starting at bottom left of page
                                x=0.5, y=0.5, font_size=12,
                                # Hide the arrow that points to the [x,y] coordinate
                                showarrow=False
                            )
                        ]
                    )
    return pie_fig

# %%
income_pie_fig_2022 = make_pie_chart(df, 2022, 'Income')
income_pie_fig_2022

# %% [markdown]
# ## Make bar charts over months in a year

# %%
def make_monthly_bar_chart(df, year, label):
    df = df[(df['Expense/Income'] == label) & (df['Year'] == year)]
    total_by_month = (df.groupby(['Month'])['Amount (EUR)'].sum()
                        .to_frame()
                        .reset_index()
                        .sort_values(by='Month')  
                        .reset_index(drop=True))
    if label == "Income":
        color_scale = px.colors.sequential.YlGn
    if label == "Expense":
        color_scale = px.colors.sequential.OrRd
    
    bar_fig = px.bar(total_by_month, x='Month', y='Amount (EUR)', text_auto='.2s', title=label+" per month", color='Amount (EUR)', color_continuous_scale=color_scale)
    # bar_fig.update_traces(marker_color='lightslategrey')
    
    return bar_fig

# %%
income_monthly_2022 = make_monthly_bar_chart(df, 2022, 'Income')
income_monthly_2022

# %% [markdown]
# ## Putting all charts together into tabs for 2022/2023

# %%
# Pie charts
income_pie_fig_2022 = make_pie_chart(df, 2022, 'Income')
expense_pie_fig_2022 = make_pie_chart(df, 2022, 'Expense')  
income_pie_fig_2023 = make_pie_chart(df, 2023, 'Income')
expense_pie_fig_2023 = make_pie_chart(df, 2023, 'Expense')

# Bar charts
income_monthly_2022 = make_monthly_bar_chart(df, 2022, 'Income')
expense_monthly_2022 = make_monthly_bar_chart(df, 2022, 'Expense')
income_monthly_2023 = make_monthly_bar_chart(df, 2023, 'Income')
expense_monthly_2023 = make_monthly_bar_chart(df, 2023, 'Expense')

# Create tabs
tabs = pn.Tabs(
    ('2022', pn.Column(
        pn.Row(
            pn.pane.Plotly(income_pie_fig_2022), 
            pn.pane.Plotly(expense_pie_fig_2022)
        ),
        pn.Row(
            pn.pane.Plotly(income_monthly_2022), 
            pn.pane.Plotly(expense_monthly_2022)
        )
    )),
    ('2023', pn.Column(
        pn.Row(
            pn.pane.Plotly(income_pie_fig_2023), 
            pn.pane.Plotly(expense_pie_fig_2023)
        ),
        pn.Row(
            pn.pane.Plotly(income_monthly_2023), 
            pn.pane.Plotly(expense_monthly_2023)
        )
    ))
)
tabs.show()
# Out:
# Launching server at http://localhost:51325

# %% [markdown]
# ## Create a Dashboard

# %%
# Dashboard template
template = pn.template.FastListTemplate(
    title='Personal Finance Dashboard',
    sidebar=[pn.pane.Markdown("# Income Expense analysis"), 
             pn.pane.Markdown("Overview of income and expense based on my bank transactions. Categories are obtained using local LLMs."),
             pn.pane.PNG("picture.png", sizing_mode="scale_both")
             ],
    main=[pn.Row(pn.Column(pn.Row(tabs)
                           )
                ),
                ],
    # accent_base_color="#88d8b0",
    header_background="#c0b9dd",
)

template.show()
# Out:
# Launching server at http://localhost:49711
